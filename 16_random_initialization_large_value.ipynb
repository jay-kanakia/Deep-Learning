# %% [markdown]
# <a href="https://colab.research.google.com/github/jay-kanakia/Deep-Learning/blob/main/16_random_initialization_large_value.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from mlxtend.plotting import plot_decision_regions
import numpy as np

# %%
import pandas as pd
df=pd.read_csv('https://raw.githubusercontent.com/jay-kanakia/Deep-Learning-CampusX/refs/heads/main/Datasets/ushape.csv',names=['X1',"X2",'y'])

# %%
X=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
def random_init(act):
  model=Sequential()
  model.add(Dense(10,activation=act,input_dim=X.shape[1]))
  model.add(Dense(1,activation='sigmoid'))
  print(model.summary())
  initial_weight=model.get_weights()

  initial_weight[0]=np.random.sample(initial_weight[0].shape)
  initial_weight[1]=np.random.sample(initial_weight[1].shape)
  initial_weight[2]=np.random.sample(initial_weight[2].shape)
  initial_weight[3]=np.random.sample(initial_weight[3].shape)


  model.set_weights(initial_weight)
  model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
  history=model.fit(X,y,epochs=250,verbose=False,validation_split=0.2)

  plt.figure(figsize=(12,12))
  plt.subplot(2,2,1)
  sns.lineplot(history.history['accuracy'])
  sns.lineplot(history.history['val_accuracy'])

  plt.subplot(2,2,2)
  sns.lineplot(history.history['loss'])
  sns.lineplot(history.history['val_loss'])

  print()
  print('*'*100)
  print()

  print('new model weights are\n\n',model.get_weights())
  print()
  print('*'*100)
  print()
  plt.subplot(2,2,3)
  return plot_decision_regions(X.to_numpy(),y.astype('int').to_numpy(),clf=model)

# %%
random_init('sigmoid')
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 10)             │            30 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 41 (164.00 B)
#  Trainable params: 41 (164.00 B)
#  Non-trainable params: 0 (0.00 B)
# None
#
# ****************************************************************************************************
#
# new model weights are
#
#  [array([[ 0.9384806 ,  0.2178162 ,  0.7265778 ,  0.16783324,  0.08185936,
#          1.0847946 , -0.14435284,  1.1879709 , -0.37549505,  0.45642063],
#        [-0.19704662, -0.08142592, -0.34701714,  0.4210493 ,  0.40632612,
#          0.00539737,  0.44645733, -0.50106806,  0.8479522 , -0.45921907]],
#       dtype=float32), array([ 0.5093776 ,  0.20355771, -0.3071159 , -0.10372375, -0.01895391,
#        -0.0081319 ,  0.892299  ,  0.4949403 ,  1.0887944 ,  0.24794668],
#       dtype=float32), array([[ 0.06635283],
#        [ 0.18300493],
#        [ 0.47977415],
#        [-0.09479693],
#        [-0.13938074],
#        [ 0.1366319 ],
#        [-0.22255528],
#        [ 0.49154297],
#        [-0.3903037 ],
#        [ 0.4837705 ]], dtype=float32), array([-0.35091224], dtype=float32)]
#
# ****************************************************************************************************
#
# 45000/45000 ━━━━━━━━━━━━━━━━━━━━ 70s 2ms/step
# <Axes: >

# %%
random_init('relu')
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_2 (Dense)                 │ (None, 10)             │            30 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 41 (164.00 B)
#  Trainable params: 41 (164.00 B)
#  Non-trainable params: 0 (0.00 B)
# None
#
# ****************************************************************************************************
#
# new model weights are
#
#  [array([[ 0.57400465,  0.45643616,  0.6056726 ,  0.06114683,  0.01194568,
#          0.5391668 ,  0.4105564 ,  0.45320916,  0.27305526,  0.16811006],
#        [ 0.72776383,  0.43428424, -0.06934787, -0.08966124,  0.13761716,
#         -0.09567019,  0.19940057,  0.41484848, -0.3436344 ,  0.15872188]],
#       dtype=float32), array([ 0.82017785, -0.4490575 ,  0.25360888,  0.0131702 ,  0.27986607,
#         0.45314768,  0.44180393,  0.32954788,  0.31679615, -0.26063883],
#       dtype=float32), array([[-0.32675385],
#        [ 0.35740578],
#        [-0.10880033],
#        [ 0.23734643],
#        [ 0.51810086],
#        [ 0.51666284],
#        [ 0.2073068 ],
#        [ 0.43744862],
#        [ 0.4986489 ],
#        [ 0.56141937]], dtype=float32), array([-0.09846574], dtype=float32)]
#
# ****************************************************************************************************
#
# 45000/45000 ━━━━━━━━━━━━━━━━━━━━ 62s 1ms/step
# <Axes: >

# %%
random_init('tanh')
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                 │ (None, 10)             │            30 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 41 (164.00 B)
#  Trainable params: 41 (164.00 B)
#  Non-trainable params: 0 (0.00 B)
# None
#
# ****************************************************************************************************
#
# new model weights are
#
#  [array([[ 0.15504478,  0.4585568 ,  0.15635274,  0.02004387,  1.2970154 ,
#          0.04683799,  0.01753977,  0.8422573 , -0.05068631,  0.94562304],
#        [-0.36600333,  0.20180412, -0.3538538 , -0.3291456 ,  0.27770907,
#          0.5223554 , -0.38930953, -0.08549584, -0.48208407,  0.07798998]],
#       dtype=float32), array([-0.04371829, -0.20729443,  0.18113264, -0.2699997 ,  0.53062236,
#         0.7163025 , -0.20575558, -0.02093215,  0.27561378,  0.5227506 ],
#       dtype=float32), array([[ 0.51774734],
#        [ 0.38747245],
#        [ 0.45661926],
#        [ 0.76387143],
#        [ 0.49768832],
#        [-0.2783495 ],
#        [ 1.2205485 ],
#        [ 0.71967715],
#        [ 0.27935025],
#        [ 0.17761894]], dtype=float32), array([0.06686545], dtype=float32)]
#
# ****************************************************************************************************
#
# 45000/45000 ━━━━━━━━━━━━━━━━━━━━ 62s 1ms/step
# <Axes: >
